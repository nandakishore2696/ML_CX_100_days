# %% [markdown]
# ## Website generated url

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNGYxOTFiNjkxNDM0OGRjODJhNDE2OTRlODMyODFhOCIsInN1YiI6IjY1YmYzMzE1OWYzN2IwMDE3YzVjMDgzNCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.RoHClxlzi4pqV9EiJyYEMZLw0Yq0keM9m_JtSzJd5ko"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg","genre_ids":[18,80],"id":278,"original_language":"en","original_title":"The Shawshank Redemption","overview":"Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.","popularity":132.266,"poster_path":"/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg","release_date":"1994-09-23","title":"The Shawshank Redemption","video":false,"vote_average":8.705,"vote_count":25825},{"adult":false,"backdrop_path":"/tmU7GeKVybMWFButWEGl2M4GeiP.jpg","genre_ids":[18,80],"id":238,"original_language":"en","original_title":"The Godfather","overview":"Spanning the years 1945 to 1955, a chronicle of the fictio
# ...

# %%
data = response.content
data
# Out:
# b'{"page":1,"results":[{"adult":false,"backdrop_path":"/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg","genre_ids":[18,80],"id":278,"original_language":"en","original_title":"The Shawshank Redemption","overview":"Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.","popularity":132.266,"poster_path":"/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg","release_date":"1994-09-23","title":"The Shawshank Redemption","video":false,"vote_average":8.705,"vote_count":25825},{"adult":false,"backdrop_path":"/tmU7GeKVybMWFButWEGl2M4GeiP.jpg","genre_ids":[18,80],"id":238,"original_language":"en","original_title":"The Godfather","overview":"Spanning the years 1945 to 1955, a chronicle of the fict
# ...

# %%
type(data)
# Out:
# bytes

# %%
type(response.text)
# Out:
# str

# %% [markdown]
# ## RESPONCE

# %%
import ast
from io import StringIO
import json

json.loads(response.text)
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 132.266,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.705,
#    'vote_count': 25825},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
# ...

# %%
json.loads(response.content)
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 132.266,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.705,
#    'vote_count': 25825},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
# ...

# %%
ast.literal_eval(response.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 ast.literal_eval(response.text)
#
# File c:\ProgramData\Anaconda3\lib\ast.py:105, in literal_eval(node_or_string)
#     103                 return left - right
#     104     return _convert_signed_num(node)
# --> 105 return _convert(node_or_string)
#
# File c:\ProgramData\Anaconda3\lib\ast.py:94, in literal_eval.<locals>._convert(node)
#      92     if len(node.keys) != len(node.values):
#      93         _raise_malformed_node(node)
# ---> 94     return dict(zip(map(_convert, node.keys),
#      95                     map(_convert, node.values)))
#      96 elif isinstance(node, BinOp) and isinstance(node.op, (Add, Sub)):
#      97     left = _convert_signed_num(node.left)
#
# File c:\ProgramData\Anaconda3\lib\ast.py:85, in literal_eval.<locals>._convert(node)
# ...

# %% [markdown]
# ## url with my api key

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?api_key=24f191b6914348dc82a41694e83281a8&language=en-US&page=1"
res = requests.get(url)
res.text
# Out:
# '{"page":1,"results":[{"adult":false,"backdrop_path":"/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg","genre_ids":[18,80],"id":278,"original_language":"en","original_title":"The Shawshank Redemption","overview":"Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.","popularity":132.266,"poster_path":"/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg","release_date":"1994-09-23","title":"The Shawshank Redemption","video":false,"vote_average":8.705,"vote_count":25825},{"adult":false,"backdrop_path":"/tmU7GeKVybMWFButWEGl2M4GeiP.jpg","genre_ids":[18,80],"id":238,"original_language":"en","original_title":"The Godfather","overview":"Spanning the years 1945 to 1955, a chronicle of the ficti
# ...

# %%
json.loads(res.content)
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 132.266,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.705,
#    'vote_count': 25825},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
# ...

# %% [markdown]
# ## Collect all the data
# *   "total_pages": 463,
# *  "total_results": 9253

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?api_key=24f191b6914348dc82a41694e83281a8&language=en-US&page=1"
res = requests.get(url)
res.text
# Out:
# '{"page":1,"results":[{"adult":false,"backdrop_path":"/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg","genre_ids":[18,80],"id":278,"original_language":"en","original_title":"The Shawshank Redemption","overview":"Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.","popularity":132.266,"poster_path":"/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg","release_date":"1994-09-23","title":"The Shawshank Redemption","video":false,"vote_average":8.705,"vote_count":25825},{"adult":false,"backdrop_path":"/tmU7GeKVybMWFButWEGl2M4GeiP.jpg","genre_ids":[18,80],"id":238,"original_language":"en","original_title":"The Godfather","overview":"Spanning the years 1945 to 1955, a chronicle of the ficti
# ...

# %%
import pandas as pd

# %%
res.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 132.266,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.705,
#   'vote_count': 25825},
#  {'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
df = pd.DataFrame()
for i in range(1,464):
    url = f"https://api.themoviedb.org/3/movie/top_rated?api_key=24f191b6914348dc82a41694e83281a8&language=en-US&page={i}"
    res = requests.get(url)
    temp_df = pd.DataFrame(res.json()['results'])[['id','title', 'overview', 'popularity','vote_average', 'vote_count']]
    df = pd.concat([df,temp_df], ignore_index=True)

# %%
df
# Out:
#          id                       title  \
# 0       278    The Shawshank Redemption
# 1       238               The Godfather
# 2       240       The Godfather Part II
# 3       424            Schindler's List
# 4       129               Spirited Away
# ...     ...                         ...
# 9248  12142           Alone in the Dark
# 9249  13805              Disaster Movie
# 9250  11059           House of the Dead
# 9251  14164        Dragonball Evolution
# 9252  40016  Birdemic: Shock and Terror
#
#                                                overview  popularity  \
# 0     Framed in the 1940s for the double murder of h...     132.266
# 1     Spanning the years 1945 to 1955, a chronicle o...     113.433
# 2     In the continuing saga of the Corleone crime f...      78.453
# 3     The true story of how businessman Oskar Schind...      81.442
# 4     A young girl, Chihiro, becomes trapped in a st...     117.133
# ...

# %%
df1 = pd.DataFrame()
for i in range(1,464):
    url = f"https://api.themoviedb.org/3/movie/top_rated?api_key=24f191b6914348dc82a41694e83281a8&language=en-US&page={i}"
    res = requests.get(url)
    temp_df = pd.DataFrame(res.json()['results'])[['id','title', 'overview', 'popularity','vote_average', 'vote_count']]
    df1 = df1.append(temp_df, ignore_index = True)
# Out:
# C:\Users\nanda\AppData\Local\Temp\ipykernel_17828\2525857989.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(temp_df, ignore_index = True)
# C:\Users\nanda\AppData\Local\Temp\ipykernel_17828\2525857989.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(temp_df, ignore_index = True)
# C:\Users\nanda\AppData\Local\Temp\ipykernel_17828\2525857989.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(temp_df, ignore_index = True)
# C:\Users\nanda\AppData\Local\Temp\ipykernel_17828\2525857989.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df1
# Out:
#          id                       title  \
# 0       278    The Shawshank Redemption
# 1       238               The Godfather
# 2       240       The Godfather Part II
# 3       424            Schindler's List
# 4       129               Spirited Away
# ...     ...                         ...
# 9248  12142           Alone in the Dark
# 9249  13805              Disaster Movie
# 9250  11059           House of the Dead
# 9251  14164        Dragonball Evolution
# 9252  40016  Birdemic: Shock and Terror
#
#                                                overview  popularity  \
# 0     Framed in the 1940s for the double murder of h...     132.266
# 1     Spanning the years 1945 to 1955, a chronicle o...     113.433
# 2     In the continuing saga of the Corleone crime f...      78.453
# 3     The true story of how businessman Oskar Schind...      81.442
# 4     A young girl, Chihiro, becomes trapped in a st...     117.133
# ...
